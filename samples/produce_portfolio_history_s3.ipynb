# %% [markdown]
# # Create a Verifiable Portfolio History

# %% [markdown]
# This sample stamps a sequence of portfolio records and stores the exact record bytes in your Amazon S3 bucket. It submits locally calculated content identifiers (CIDs) instead of the portfolio contents.

# %% [markdown]
# ## Imports

# %%
# %%capture

# %pip install --quiet boto3 vbase-api
# !wget --quiet --output-document=collab_utils.py https://raw.githubusercontent.com/validityBase/vbase-py-samples-collab/main/samples/collab_utils.py

from datetime import datetime, timezone
import json
import random
from uuid import uuid4

from vbase_api import VBaseAPIClient

from collab_utils import (
    create_s3_client_from_env,
    get_cid_for_bytes,
    get_required_env,
    try_add_optional_user_secrets_to_env,
    try_add_user_secrets_to_env,
    write_s3_object,
)

# %% [markdown]
# ## Configuration

# %% [markdown]
# Each run uses a unique collection so it creates a new, independently verifiable portfolio history.

# %%
RUN_ID = f"{datetime.now(timezone.utc):%Y%m%dT%H%M%SZ}-{uuid4().hex[:8]}"
COLLECTION_NAME = f"Google Colab Portfolio Sample {RUN_ID}"
COLLECTION_DESCRIPTION = "A verifiable sample portfolio history stored in Amazon S3."

# %% [markdown]
# The number of sample portfolios to create.

# %%
N_TIME_PERIODS = 10

# %% [markdown]
# The S3 prefix used for the portfolio records.

# %%
S3_PREFIX = "vbase-samples/portfolio-history"

# %% [markdown]
# ## Setup

# %% [markdown]
# Load the vBase and AWS credentials from Google Colab secrets.

# %%
try_add_user_secrets_to_env([
    "VBASE_API_KEY",
    "AWS_ACCESS_KEY_ID",
    "AWS_SECRET_ACCESS_KEY",
    "AWS_DEFAULT_REGION",
    "AWS_S3_BUCKET",
])
try_add_optional_user_secrets_to_env(["AWS_SESSION_TOKEN"])

# %% [markdown]
# Connect to AWS.

# %%
s3_client = create_s3_client_from_env()
bucket_name = get_required_env("AWS_S3_BUCKET")

# %% [markdown]
# Connect to vBase.

# %%
vbase_client = VBaseAPIClient(api_key=get_required_env("VBASE_API_KEY"))

# %% [markdown]
# ## Create and Stamp Portfolios

# %% [markdown]
# Create a collection for this run.

# %%
collection = vbase_client.create_collection(
    name=COLLECTION_NAME,
    description=COLLECTION_DESCRIPTION,
)

collection_prefix = f"{S3_PREFIX}/{collection.cid}"
owner_address = vbase_client.get_current_user().last_address
if not owner_address:
    raise RuntimeError("The current vBase account does not have an owner address.")
print(f"Collection: {collection.name}")
print(f"Collection CID: {collection.cid}")
print(f"Owner address: {owner_address}")

# %% [markdown]
# Create sample portfolios.

# %%
random_generator = random.Random(1234)
for period in range(N_TIME_PERIODS):
    portfolio = {
        "SPY": round(random_generator.random() * 2 - 1, 2),
        "TSLA": round(random_generator.random() * 2 - 1, 2),
        "BTCUSD": round(random_generator.random() * 2 - 1, 2),
        "JPM:CDS:5": round(random_generator.random() * 2 - 1, 2),
    }
    record_bytes = json.dumps(
        portfolio,
        sort_keys=True,
        separators=(",", ":"),
    ).encode("utf-8")
    object_cid = get_cid_for_bytes(record_bytes)

    stamp = vbase_client.create_stamp(
        data_cid=object_cid,
        collection_cid=collection.cid,
        store_stamped_file=False,
        idempotent=True,
        idempotency_window=0,
    )
    object_key = write_s3_object(
        s3_client,
        bucket_name,
        collection_prefix,
        f"portfolio_{period:02d}.json",
        record_bytes,
    )
    print(f"{object_key}: {stamp.commitment_receipt.object_cid}")

# %% [markdown]
# Display the S3 location and the information needed to verify the history.

# %%
print(f"Portfolio history: s3://{bucket_name}/{collection_prefix}/")
print(f"Collection name: {collection.name}")
print(f"Collection CID: {collection.cid}")
print(f"Owner address: {owner_address}")
vbase_client.close()

# %% [markdown]
# ## Summary

# %% [markdown]
# **Process**
#
# - The sample generated deterministic portfolio records.
# - It calculated each CID locally and submitted it instead of the portfolio contents.
# - It stored the exact portfolio bytes in your S3 bucket.

# %% [markdown]
# **Key implications**
#
# - The portfolio contents remain under your control.
# - Anyone with the records, collection CID, and expected owner address can verify their integrity and timestamps.
# - Analytics can be recalculated from the verified records.
